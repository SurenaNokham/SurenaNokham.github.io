# %%
# Load files
from os.path import basename, exists


def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + local)


download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkstats2.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkplot.py")

# %%
# Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import thinkstats2
import thinkplot

# %%
# Read csv file and assign data to variable
outbreaks_data = pd.read_csv('FoodborneOutbreaks.csv')

# %% [markdown]
# # Include a histogram of each of the 5 variables – in your summary and analysis, identify any outliers and explain the reasoning for them being outliers and how you believe they should be handled (Chapter 2).
# # Include the other descriptive characteristics about the variables: Mean, Mode, Spread, and Tails (Chapter 2).

# %% [markdown]
# # Variable 1 - Month

# %%
# Calculate the frequency of outbreaks by month
outbreaks_by_month = outbreaks_data['Month'].value_counts().head(12)

# Plot the frequency using Pandas plotting function
outbreaks_by_month.plot.bar()
plt.title('Outbreak Case Frequency by Month (2005-2015)')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.show()

# No outliers oberved.

# %%
# Descriptive statistics - Month
print('Mean:', outbreaks_by_month.mean())
print('Mode:', outbreaks_by_month.mode().values)
print('Variance:', outbreaks_by_month.var())
print('Standard Deviation:', outbreaks_by_month.std())

# Calculate the spread (range)
spread_month = outbreaks_by_month.max() - outbreaks_by_month.min()

# Calculate the tail (minimum and maximum values)
min_month = outbreaks_by_month.min()
max_month = outbreaks_by_month.max()

print("Tail (Minimum):", min_month)
print("Tail (Maximum):", max_month)
print("Spread (Range):", spread_month)
# Out:
# Mean: 404.25
# Mode: [311 330 332 349 380 415 426 427 428 480 481 492]
# Variance: 4006.2045454545455
# Standard Deviation: 63.29458543552162
# Tail (Minimum): 311
# Tail (Maximum): 492
# Spread (Range): 181

# %% [markdown]
# # Variable 2 - Year

# %%
# Plot the histogram
plt.hist(outbreaks_data['Year'], bins=10, color='pink', edgecolor='black')

# Set the title, x-axis label and y-axis label
plt.title('Confirmed Cases of Outbreak by Year')
plt.xlabel('Year')
plt.ylabel('Confirmed Cases')

#Display the plot          
plt.show()

# No outliers observed.

# %%
# Descriptive statistics - Year
print('Mean:', outbreaks_data['Year'].mean())
print('Mode:', outbreaks_data['Year'].mode().values)
print('Variance:', outbreaks_data['Year'].var())
print('Standard Deviation:', outbreaks_data['Year'].std())

# Calculate the spread (range)
spread_year = outbreaks_data['Year'].max() - outbreaks_data['Year'].min()

# Calculate the tail (minimum and maximum values)
min_year = outbreaks_data['Year'].min()
max_year = outbreaks_data['Year'].max()

print("Tail (Minimum):", min_year)
print("Tail (Maximum):", max_year)
print("Spread (Range):", spread_year)
# Out:
# Mean: 2009.8324056895485
# Mode: [2006]
# Variance: 10.313143469196575
# Standard Deviation: 3.2114083311214996
# Tail (Minimum): 2005
# Tail (Maximum): 2015
# Spread (Range): 10

# %% [markdown]
# # Variable 3 - State

# %%
# Calculate which states had the most outbreaks
topstate = outbreaks_data['State'].value_counts().head(6)

# # Plot the frequency 
plt.bar(topstate.index, topstate.values, color='orange', edgecolor='black')
plt.title('Top States with the Highest Frequency of Outbreak')
plt.xlabel('State')
plt.ylabel('Frequency')
plt.show()

# No outliers observed.

# %%
# Descriptive statistics - State
print('Mean:', topstate.mean())
print('Mode:', topstate.mode().values)
print('Variance:', topstate.var())
print('Standard Deviation:', topstate.std())

# Calculate the spread (range)
spread_state = topstate.max() - topstate.min()

# Calculate the tail (minimum and maximum values)
min_state = topstate.min()
max_state = topstate.max()

print("Tail (Minimum):", min_state)
print("Tail (Maximum):", max_state)
print("Spread (Range):", spread_state)
# Out:
# Mean: 306.0
# Mode: [233 238 284 311 381 389]
# Variance: 4595.2
# Standard Deviation: 67.78790452580755
# Tail (Minimum): 233
# Tail (Maximum): 389
# Spread (Range): 156

# %% [markdown]
# # Variable 4 - Genus

# %%
# Calculate the frequency of outbreaks by genus
genus_data = outbreaks_data['Genus'].value_counts().head(10)

# Plot the frequency 
genus_data.plot.bar(color='purple')
plt.title('Most Common Genus Types in Foodborne Illnesses')
plt.xlabel('Genus')
plt.ylabel('Frequency')
plt.show()

# %%
# Descriptive statistics - Genus
print('Mean:', genus_data.mean())
print('Mode:', genus_data.mode().values)
print('Variance:', genus_data.var())
print('Standard Deviation:', genus_data.std())

# Calculate the spread (range)
spread_genus = genus_data.max() - genus_data.min()

print("Spread (Range):", spread_genus)

# Tail not computable but extends to the right
# Out:
# Mean: 457.9
# Mode: [  47   62   80  125  163  230  234  309 1293 2036]
# Variance: 442022.7666666667
# Standard Deviation: 664.8479274741455
# Spread (Range): 1989

# %% [markdown]
# # Variable 5 - Ingredient

# %%
# Calculate contaminated ingredients
top_ingredient = outbreaks_data['Ingredient'].value_counts().head(6)

# Set title, x-axis label, and y-axis label
plt.bar(top_ingredient.index, top_ingredient.values, color='green')
plt.title('Top 6 Contaminated Ingredients in Outbreaks')
plt.xlabel('Ingredient')
plt.ylabel('Frequency')

# Display histogram
plt.show()

# %%
# Descriptive statistics - Ingredient
print('Mean:', top_ingredient.mean())
print('Mode:', top_ingredient.mode().values)
print('Variance:', top_ingredient.var())
print('Standard Deviation:', top_ingredient.std())

# Calculate the spread (range)
spread_ingredient = top_ingredient.max() - top_ingredient.min()

# Calculate the tail (minimum and maximum values)
min_ingredient = top_ingredient.min()
max_ingredient = top_ingredient.max()

print("Tail (Minimum):", min_ingredient)
print("Tail (Maximum):", max_ingredient)
print("Spread (Range):", spread_ingredient)
# Out:
# Mean: 39.833333333333336
# Mode: [30 33 35 40 43 58]
# Variance: 101.36666666666667
# Standard Deviation: 10.068101443006356
# Tail (Minimum): 30
# Tail (Maximum): 58
# Spread (Range): 28

# %% [markdown]
# # Using pg. 29 of your text as an example, compare two scenarios in your data using a PMF. Reminder, this isn’t comparing two variables against each other – it is the same variable, but a different scenario. Almost like a filter. The example in the book is first babies compared to all other babies, it is still the same variable, but breaking the data out based on criteria we are exploring (Chapter 3)

# %%
# Create Scenario 1: Outbreaks in California
# Create Scenario 2: Outbreaks in all other states
scenario1 = 'California'
scenario2 = 'Other States'

# %%
# Create PMF for each scenario
pmf_scenario1 = outbreaks_data.loc[outbreaks_data['State'] == scenario1, 'State'].value_counts(normalize=True)
pmf_scenario2 = outbreaks_data.loc[outbreaks_data['State'] != scenario1, 'State'].value_counts(normalize=True)

# %%
# Plot PMFs
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
pmf_scenario1.plot(kind='bar')
plt.title('PMF of Outbreaks in ' + scenario1)
plt.xlabel('Number of Outbreaks')
plt.ylabel('Probability')

plt.subplot(2, 1, 2)
pmf_scenario2.plot(kind='bar')
plt.title('PMF of Outbreaks in ' + scenario2)
plt.xlabel('Number of Outbreaks')
plt.ylabel('Probability')

plt.show()

# %% [markdown]
# # Create 1 CDF with one of your variables, using page 41-44 as your guide, what does this tell you about your variable and how does it address the question you are trying to answer (Chapter 4).

# %%
# Create a mapping dictionary for months
month_mapping = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

# Convert the "Month" column to integers
outbreaks_data['Month'] = outbreaks_data['Month'].map(month_mapping)

# %%
# Filter the data to include only relevant columns and non-null values
data = outbreaks_data['Month'].dropna()

# Compute the CDF
cdf = thinkstats2.Cdf(data)

# Plot the CDF
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='Month', ylabel='CDF', title='CDF of Foodborne Illnesses by Month')

# Show the plot
thinkplot.show()

# %%
# The CDF shows how the cumulative probability of foodborne illnesses changes as we move through the months.
# If the curve is steeper in certain months, it suggests a higher prevalence of foodborne illnesses during those 
# months compared to others. If the curve is less steep, it indicates a lower prevalence of foodborne illnesses 
# during those months. 

# As shown above, the CDF shows a slightly steeper (blink and you'll miss it) curve during certain months
# (e.g., spring/summer months), this would suggests there is a higher prevalence of foodborne illnesses during 
# those seasons. Overall, there are minimal changes through the months, indicating a more consistent 
# prevalence of foodborne illnesses throughout the year.

# %% [markdown]
# # Plot 1 analytical distribution and provide your analysis on how it applies to the dataset you have chosen (Chapter 5).

# %%
# Month columns converted to numeric values and NaN are dropped
months = pd.to_numeric(outbreaks_data['Month'], errors='coerce').dropna().values

# Calculate mean and std deviation
mean = np.mean(months)
std_dev = np.std(months)

# Random 1000 samples generated
normal_dist = np.random.normal(mean, std_dev, 1000)

# Plot histogram
plt.hist(normal_dist, bins=30, density=True, alpha=0.5, color='yellow', edgecolor='black')
plt.xlabel('Month')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Months')
plt.show()

# %%
# Looking at the generated normal distribution and comparing it the Outbreak dataset, we can get an idea of when 
# outbreaks will occur for the different months. The normal distribution peaks between 5.0-7.5 which coalates
# to the following months, respectively: May, June, July, mid-August. With it peaking in the summer months, there 
# is a high probability of outbreaks to occur. This distribution is evenly spread, indicating a relatively 
# consistent occurrence of outbreaks throughout the year.

# %% [markdown]
# # Create two scatter plots comparing two variables and provide your analysis on correlation and causation. Remember, covariance, Pearson’s correlation, and Non-Linear Relationships should also be considered during your analysis (Chapter 7).

# %%
# Remove rows with missing values
outbreaks_data = outbreaks_data[['Illnesses', 'Hospitalizations']].dropna()

# %%
# Select the variables of interest
illnesses = outbreaks_data['Illnesses']
hospitalizations = outbreaks_data['Hospitalizations']

# Create Scatter plot
plt.scatter(illnesses, hospitalizations)
plt.xlabel('Reported Illnesses')
plt.ylabel('Hospitalizations')
plt.title('Scatter Plot of Illnesses vs Hospitalizations')
plt.show()

# Calculate Correlation analysis
correlation = np.corrcoef(illnesses, hospitalizations)[0,1]
print('Correlation coefficient:', correlation)

# Causation analysis
covariance = np.cov(illnesses, hospitalizations)[0,1]
print('Covariance:', covariance)

# Pearson's correlation
pearson_corr = illnesses.corr(hospitalizations)
print("Pearson's correlation coefficient:", pearson_corr)

# Non-linear relationship analysis
sns.regplot(x=illnesses, y=hospitalizations, scatter_kws={'alpha':0.5, 'color':'blue'})
plt.xlabel('Reported Illnesses')
plt.ylabel('Hospitalizations')
plt.title('Scatter Plot with Regression Line')
plt.show()
# Out:
# Correlation coefficient: 0.5049863642388567
# Covariance: 275.7228274083509
# Pearson's correlation coefficient: 0.5049863642388567

# %%
# Correlation: 
# The scatter plot shows a positive linear relationship between the "Illnesses" and "Hospitalizations"
# variables. As the number of illnesses increases, hospitalizations will increase too. The correlation
# coefficient is 0.50 which indicates a strong correlation (strong range is between 0.50-1.0).

# Causation:
#The high correlation between "Illnesses" and "Hospitalizations" suggests that there is a relationship between
# the two variables. However, it doesn't necessarily mean that one variable is causing the other. Other factors
# could be contributing to both variables. Further analysis is needed to establish a causal relationship.

# Covariance:
# A positive, high covariance (275.72) suggests a positive relationship between the two variables but it does not
# tell us the strength of the relationship.

# Pearsons Correlation:
# With a value of 0.50, the positive coefficient supports a positive linear relationship between both variables.

# %% [markdown]
# # Conduct a test on your hypothesis using one of the methods covered in Chapter 9.

# %%
# Import libraries
import pandas as pd
import numpy as np

# Read csv
outbreaks_data = pd.read_csv('FoodborneOutbreaks.csv')

# %%
# Extract the relevant columns from the dataset
months = outbreaks_data['Month']
cases = outbreaks_data['Illnesses']

# Create a boolean mask to identify summer months (June, July, August)
is_summer = (months.isin(['June', 'July', 'August']))

# Separate the cases for summer and non-summer months
summer_cases = cases[is_summer]
non_summer_cases = cases[~is_summer]

# %%
# Calculate observed test statistic
observed_statistic = np.mean(summer_cases) - np.mean(non_summer_cases)

# %%
# Perform permutation test
num_permutations = 1000
test_statistics = []

for _ in range(num_permutations):
    # Shuffle the summer and non-summer cases
    shuffled_cases = np.random.permutation(cases)

    # Calculate the test statistic using shuffled cases
    shuffled_summer_cases = shuffled_cases[is_summer]
    shuffled_non_summer_cases = shuffled_cases[~is_summer]
    test_statistic = np.mean(shuffled_summer_cases) - np.mean(shuffled_non_summer_cases)

    test_statistics.append(test_statistic)

# %%
# Calculate the p-value
p_value = (np.abs(test_statistics) >= np.abs(observed_statistic)).mean()

# %%
# Interpret results
alpha = 0.05  # significance level

if p_value < alpha:
    print("There is evidence to reject the null hypothesis.")
else:
    print("There is not enough evidence to reject the null hypothesis.")
# Out:
# There is not enough evidence to reject the null hypothesis.

# %% [markdown]
# # For this project, conduct a regression analysis on either one dependent and one explanatory variable, or multiple explanatory variables (Chapter 10 & 11).

# %%
# Convert 'Month' column to datetime objects
outbreaks_data['Month'] = pd.to_datetime(outbreaks_data['Month'], format='%B')

# Extract the month component as numeric values
outbreaks_data['Month'] = outbreaks_data['Month'].dt.month

# %%
# Import library
import statsmodels.api as sm

# Perform regression analysis
y = outbreaks_data['Illnesses']
x = outbreaks_data['Month']
x = sm.add_constant(x)

model = sm.OLS(y, x)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Illnesses   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     6.175
# Date:                Sat, 03 Jun 2023   Prob (F-statistic):             0.0130
# Time:                        16:34:42   Log-Likelihood:                -27149.
# No. Observations:                4851   AIC:                         5.430e+04
# Df Residuals:                    4849   BIC:                         5.432e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.4794      2.031     14.513      0.000      25.497      33.462
# ...
